# %%
from jogadores  import Tabela_Jogadores
from caminhos   import pasta_dados

# %%
tabela = Tabela_Jogadores(pasta_dados / "players.csv", 2000)

# %%
neymar = tabela[190871]

# %%
print(neymar)
# Out:
# sofifa_id           190871
# short_name          Neymar Jr
# long_name           Neymar da Silva Santos Junior
# player_positions    LW, CAM
# nationality         Brazil
# club_name           Paris Saint-Germain
# league_name         French Ligue 1
# rating              None
