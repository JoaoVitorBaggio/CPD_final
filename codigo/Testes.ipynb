# %% [markdown]
# ## Testes de Estruturas e Pesquisas

# %% [markdown]
# ### Tabela Hash dos Jogadores

# %% [markdown]
# Inicializa

# %%
from jogadores  import Tabela_Jogadores
from caminhos   import pasta_dados

tabela = Tabela_Jogadores(
    caminho = pasta_dados / "players.csv",
    tamanho = 2000
    )

# %% [markdown]
# Pesquisa

# %%
sofifa_id = 158023

jogador = tabela[sofifa_id]
jogador.imprimir()
# Out:
# sofifa_id          158023
# short_name         L. Messi
# long_name          Lionel Andres Messi Cuccittini
# player_positions   RW, ST, CF
# nationality        Argentina
# club_name          FC Barcelona
# league_name        Spain Primera Division
# rating             -1
# count              0

# %% [markdown]
# ### Árvore de Prefixos

# %% [markdown]
# Inicializa

# %%
from TST        import TST
from caminhos   import pasta_dados
from jogadores  import ordenar_jogador_por_nota

arvore = TST(caminho=pasta_dados / "players.csv")

# %% [markdown]
# Pesquisa

# %%
prefixo = "Maria"

ids = arvore.collect_words_with_prefix(prefixo)
jogadores = [tabela[sofifa_id] for sofifa_id in ids]
ordenar_jogador_por_nota(jogadores)
tabela.imprimir_jogadores(jogadores)
# Out:
# sofifa_id, short_name, long_name, player_positions, nationality, club_name, league_name, rating, count
# 251879, M. Serban, Marian Cristinel Serban, CDM, Romania, Academica Clinceni, Romanian Liga I, -1, 0
# 258373, M. Danciu, Marian Danciu, RW, Romania, Universitatea Craiova, Romanian Liga I, -1, 0
# 247969, M. Pleasca, Marian Pleasca, RB, Romania, UTA Arad, Romanian Liga I, -1, 0
# 248013, M. Tarsa, Marian Tarsa, CM, Romania, FC Botoşani, Romanian Liga I, -1, 0
# 215148, M. Bittolo, Mariano Bittolo, LB, LWB, Argentina, Newell's Old Boys, Argentina Primera División, -1, 0
# 221639, Mariano, Mariano Diaz Mejia, ST, Dominican Republic, Real Madrid, Spain Primera Division, -1, 0
# 173857, M. Andujar, Mariano Gonzalo Andujar, GK, Argentina, Estudiantes de La Plata, Argentina Primera División, -1, 0

# %% [markdown]
# ### Usuarios e Revisões

# %% [markdown]
# Inicializa

# %% [markdown]
# Pesquisa

# %% [markdown]
# ### Tags

# %% [markdown]
# Inicializa

# %% [markdown]
# Pesquisa
