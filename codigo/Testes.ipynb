# %% [markdown]
# ## Testes de Estruturas e Pesquisas

# %% [markdown]
# ### Tabela Hash dos Jogadores

# %% [markdown]
# Inicializa

# %%
from jogadores  import Tabela_Jogadores
from caminhos   import pasta_dados

tabela = Tabela_Jogadores(
    caminho = pasta_dados / "players.csv",
    tamanho = 2000
    )

# %% [markdown]
# Pesquisa

# %%
sofifa_id = 256631

jogador = tabela[sofifa_id]
jogador.imprimir()
# Out:
# sofifa_id          256631
# short_name         B. Montano
# long_name          Brayan Stiven Montano Montano
# player_positions   CB
# nationality        Colombia
# club_name          Deportivo Cali
# league_name        Colombian Liga Postobón
# rating             -1
# count              0

# %% [markdown]
# ### Árvore de Prefixos

# %% [markdown]
# Inicializa

# %%
from TST        import TST
from caminhos   import pasta_dados
from jogadores  import ordenar_jogador_por_nota

arvore = TST(caminho=pasta_dados / "players.csv")

# %% [markdown]
# Pesquisa

# %%
prefixo = "Ali"

ids = arvore.collect_words_with_prefix(prefixo)
jogadores = [tabela[sofifa_id] for sofifa_id in ids]
ordenar_jogador_por_nota(jogadores)
tabela.imprimir_jogadores(jogadores)

# %% [markdown]
# ### Usuarios e Revisões

# %% [markdown]
# Inicializa

# %% [markdown]
# Pesquisa

# %% [markdown]
# ### Tags

# %% [markdown]
# Inicializa

# %% [markdown]
# Pesquisa
